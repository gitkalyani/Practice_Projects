# %% [markdown]
# ### Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')  
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# ### Firstly we are going to encode the data which is in object form to integer

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.iloc[:,0]=le.fit_transform(df.iloc[:,0])
df.iloc[:,1]=le.fit_transform(df.iloc[:,1])
df.iloc[:,2]=le.fit_transform(df.iloc[:,2])
df.iloc[:,3]=le.fit_transform(df.iloc[:,3])
df.iloc[:,4]=le.fit_transform(df.iloc[:,4])
df.iloc[:,5]=le.fit_transform(df.iloc[:,5])
df.iloc[:,6]=le.fit_transform(df.iloc[:,6])
df.iloc[:,7]=le.fit_transform(df.iloc[:,7])
df.iloc[:,8]=le.fit_transform(df.iloc[:,8])
df.iloc[:,9]=le.fit_transform(df.iloc[:,9])
df.iloc[:,10]=le.fit_transform(df.iloc[:,10])
df.iloc[:,11]=le.fit_transform(df.iloc[:,11])
df.iloc[:,12]=le.fit_transform(df.iloc[:,12])
df.iloc[:,13]=le.fit_transform(df.iloc[:,13])
df.iloc[:,14]=le.fit_transform(df.iloc[:,14])
df.iloc[:,15]=le.fit_transform(df.iloc[:,15])
df.iloc[:,16]=le.fit_transform(df.iloc[:,16])
df.iloc[:,17]=le.fit_transform(df.iloc[:,17])
df.iloc[:,18]=le.fit_transform(df.iloc[:,18])
df.iloc[:,19]=le.fit_transform(df.iloc[:,19])
df.iloc[:,20]=le.fit_transform(df.iloc[:,20])
df.iloc[:,21]=le.fit_transform(df.iloc[:,21])
df.iloc[:,22]=le.fit_transform(df.iloc[:,22])
df.iloc[:,23]=le.fit_transform(df.iloc[:,23])
df.iloc[:,24]=le.fit_transform(df.iloc[:,24])
df.iloc[:,25]=le.fit_transform(df.iloc[:,25])
df.iloc[:,26]=le.fit_transform(df.iloc[:,26])
df.iloc[:,27]=le.fit_transform(df.iloc[:,27])
df.iloc[:,28]=le.fit_transform(df.iloc[:,28])
df.iloc[:,29]=le.fit_transform(df.iloc[:,29])
df.iloc[:,30]=le.fit_transform(df.iloc[:,30])
df.iloc[:,31]=le.fit_transform(df.iloc[:,31])
df.iloc[:,32]=le.fit_transform(df.iloc[:,32])
df.iloc[:,33]=le.fit_transform(df.iloc[:,33])
df.iloc[:,34]=le.fit_transform(df.iloc[:,34])
df.iloc[:,35]=le.fit_transform(df.iloc[:,35])
df.iloc[:,36]=le.fit_transform(df.iloc[:,36])
df.iloc[:,37]=le.fit_transform(df.iloc[:,37])
df.iloc[:,38]=le.fit_transform(df.iloc[:,38])
df.iloc[:,39]=le.fit_transform(df.iloc[:,39])
df.iloc[:,40]=le.fit_transform(df.iloc[:,40])
df.iloc[:,41]=le.fit_transform(df.iloc[:,41])
df.iloc[:,42]=le.fit_transform(df.iloc[:,42])

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    int64
#  1   PH-121     571 non-null    int64
#  2   HS-101     571 non-null    int64
#  3   CY-105     571 non-null    int64
#  4   HS-105/12  571 non-null    int64
#  5   MT-111     571 non-null    int64
#  6   CS-105     571 non-null    int64
#  7   CS-106     571 non-null    int64
#  8   EL-102     571 non-null    int64
#  9   EE-119     571 non-null    int64
#  10  ME-107     571 non-null    int64
#  11  CS-107     571 non-null    int64
#  12  HS-205/20  571 non-null    int64
#  13  MT-222     571 non-null    int64
#  14  EE-222     571 non-null    int64
#  15  MT-224     571 non-null    int64
#  16  CS-210     571 non-null    int64
#  17  CS-211     571 non-null    int64
#  18  CS-203     571 non-null    int64
#  19  CS-214     571 non-null    int64
# ...

# %%
df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean   285.000000    3.781086    5.071804    2.921191    4.264448    3.935201
# std    164.977776    3.046895    2.785317    2.992228    3.216478    3.034481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    142.500000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    285.000000    3.000000    5.000000    2.000000    4.000000    4.000000
# 75%    427.500000    6.000000    7.000000    5.000000    7.000000    6.000000
# max    570.000000   12.000000   11.000000   13.000000   13.000000   13.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.838879    4.161121    3.998249    3.921191  ...    4.299475
# ...

# %%
df.isnull()
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0       False   False   False   False      False   False   False   False
# 1       False   False   False   False      False   False   False   False
# 2       False   False   False   False      False   False   False   False
# 3       False   False   False   False      False   False   False   False
# 4       False   False   False   False      False   False   False   False
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566     False   False   False   False      False   False   False   False
# 567     False   False   False   False      False   False   False   False
# 568     False   False   False   False      False   False   False   False
# 569     False   False   False   False      False   False   False   False
# 570     False   False   False   False      False   False   False   False
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# ### Observations

# %% [markdown]
# . No null values are present
#
# . As mean and meadian is almost same for all columns then skewness might be not present
#
# . Standard deviation is as near as mean then the data may be normaly distributed

# %% [markdown]
# ### Checking for unique values for Target Variable

# %%
 df[ 'CGPA'].nunique()
# Out:
# 491

# %% [markdown]
# ### As the the data entries are 571 and the unique values for the Target variable is 491, it is a Regression Problem

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns
# %matplotlib inline

sns.heatmap(df.isnull(),cmap="rainbow",yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### No null values are present

# %% [markdown]
# ### Lets visualise the relationship between target variable and other features

# %%
import matplotlib.pyplot as plt
sns.set_style('whitegrid')    # male & female student representaion on countplot
sns.countplot(x='PH-121',data=df,palette='plasma')
# Out:
# <AxesSubplot:xlabel='PH-121', ylabel='count'>

# %%
sns.set_style('whitegrid')    # male & female student representaion on countplot
sns.countplot(x='HS-101',data=df,palette='plasma')
# Out:
# <AxesSubplot:xlabel='HS-101', ylabel='count'>

# %%
b = sns.kdeplot(df['CY-105'])    # Kernel Density Estimations
b.axes.set_title('Grade of students for CY-105')
b.set_xlabel('CY-105')
b.set_ylabel('Count')
plt.show()

# %%
b = sns.kdeplot(df['HS-105/12'])    # Kernel Density Estimations
b.axes.set_title('Grade of students for HS-105/12')
b.set_xlabel('HS-105/12')
b.set_ylabel('Count')
plt.show()

# %%
b = sns.countplot(x='PH-121',hue='HS-101', data=df, palette='inferno')
b.axes.set_title('Grades  of students in different years')
b.set_xlabel("PH-121")
b.set_ylabel("Count")
plt.show()

# %%
b = sns.countplot(x='CY-105',hue='CS-212', data=df, palette='inferno')
b.axes.set_title('Grades  of students in different years')
b.set_xlabel("CY-105")
b.set_ylabel("Count")
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='CS-212',data=df,palette='magma')
# Out:
# <AxesSubplot:xlabel='CS-212', ylabel='count'>

# %% [markdown]
# ### EDA - Exploratory Data Analysis

# %%
# Checking for  skeweness

df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105       1.001752
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# ...

# %% [markdown]
# Skewness is  in CY-105, HS-205/20, CS-406, CS-414

# %% [markdown]
# ### Removing skeweness using  cuberoot method

# %%
df['CY-105'] = np.cbrt(df['CY-105'])

# %% [markdown]
# ### check the revised skeweness after romving the skeweness using distplot

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105      -0.397919
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# ...

# %%
sns.distplot(df['CY-105'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df['HS-205/20'] = np.cbrt(df['HS-205/20'])

# %%
sns.distplot(df['HS-205/20'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105      -0.397919
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20   -0.958609
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# ...

# %%
df['CS-406'] = np.cbrt(df['CS-406'])

# %%
sns.distplot(df['CS-406'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df['CS-414'] = np.cbrt(df['CS-414'])

# %%
sns.distplot(df['CS-414'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105      -0.397919
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20   -0.958609
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406      -0.671251
# CS-414      -0.382579
# CS-419       0.773674
# CS-423       0.627219
# ...

# %%
cor = df.corr()
cor
# Out:
#            Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111  \
# Seat No.   1.000000  0.068592 -0.044036 -0.347813  -0.270623 -0.196181
# PH-121     0.068592  1.000000  0.382436  0.494438   0.508231  0.487830
# HS-101    -0.044036  0.382436  1.000000  0.277985   0.473146  0.441847
# CY-105    -0.347813  0.494438  0.277985  1.000000   0.457361  0.480726
# HS-105/12 -0.270623  0.508231  0.473146  0.457361   1.000000  0.505049
# MT-111    -0.196181  0.487830  0.441847  0.480726   0.505049  1.000000
# CS-105     0.000623  0.609990  0.400713  0.516027   0.493581  0.416784
# CS-106    -0.316346  0.319649  0.321346  0.359569   0.516214  0.528063
# EL-102    -0.032695  0.443420  0.359801  0.362407   0.373136  0.568940
# EE-119     0.051663  0.589250  0.323381  0.451806   0.425518  0.422151
# ME-107     0.080960  0.548820  0.345819  0.457210   0.334125  0.478874
# CS-107    -0.065632  0.501814  0.507674  0.396485   0.550732  0.503985
# ...

# %%
#Visualize the correlation matrix by plotting heatmap
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),linewidths = 0.1, fmt = ".1g", linecolor = "black", annot = True, cmap = "Blues_r")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# ### To visualise the correlation between the label and features using bar plot

# %%
plt.figure(figsize = (22,7))

df.corr()["CGPA"].sort_values(ascending = False).drop(["CGPA"]).plot(kind = 'bar', color = 'm')

plt.xlabel('Feature', fontsize = 15)

plt.ylabel('Target', fontsize = 15)

plt.title('correlation between label and features using barplot', fontsize=20)

plt.show()

# %% [markdown]
# ### Multicollinearity problem is present in the dataset

# %% [markdown]
# ### Saperating features and label

# %%
x= df.drop("CGPA",axis=1)
y= df["CGPA"]

# %% [markdown]
# ### Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#      Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# 0   -1.729020  0.400402  1.770900  1.215446   0.540054  1.340711  2.657832
# 1   -1.722953 -1.242052  1.411559  1.416605   1.473569  0.351207  1.173242
# 2   -1.716887 -1.242052 -0.744483 -1.389651   0.228883  0.021373 -1.053643
# 3   -1.710820  1.714365  0.692879  1.416605   1.473569  1.670546 -0.311348
# 4   -1.704753 -0.585070 -1.103823  0.251457  -0.082289 -1.297966 -1.053643
# ..        ...       ...       ...       ...        ...       ...       ...
# 566  1.704753 -0.256579 -1.822504 -1.389651  -0.704632 -0.968131 -1.053643
# 567  1.710820 -0.913561 -1.822504 -1.389651  -1.326975 -1.297966 -1.053643
# 568  1.716887 -0.256579 -1.822504  0.251457  -0.082289 -1.297966 -1.053643
# 569  1.722953 -1.242052 -0.385142  1.319759  -1.326975  1.670546  2.657832
# 570  1.729020  0.728893  1.411559  1.319759   0.540054  0.681042  2.657832
#
# ...

# %% [markdown]
# ### To fix multicolinearity use VIF ie Varieance Inflation Factor

# %%
#VIF is used to identify and reduce the multicolinearity

#Finding VIF in each scaled column ie x.shape[1]  (1/(1-R2))


from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values   Features
# 0     3.953077   Seat No.
# 1     3.032729     PH-121
# 2     1.789905     HS-101
# 3     2.303352     CY-105
# 4     2.445266  HS-105/12
# 5     2.706133     MT-111
# 6     2.422022     CS-105
# 7     2.072860     CS-106
# 8     2.162506     EL-102
# 9     2.189016     EE-119
# 10    2.487839     ME-107
# 11    2.566606     CS-107
# 12    1.653622  HS-205/20
# 13    2.492734     MT-222
# 14    2.669182     EE-222
# 15    3.171006     MT-224
# 16    3.866954     CS-210
# 17    2.835834     CS-211
# 18    2.817652     CS-203
# 19    2.976531     CS-214
# 20    2.809478     EE-217
# 21    3.143255     CS-212
# 22    3.333834     CS-215
# 23    2.277279     MT-331
# 24    2.478879     EF-303
# 25    3.070544     HS-304
# 26    3.506748     CS-301
# 27    3.169721     CS-302
# 28    3.277516     TC-383
# 29    2.265429     MT-442
# 30    3.705274     EL-332
# 31    2.832256     CS-318
# 32    4.039549     CS-306
# 33    3.703555     CS-312
# ...

# %%
b = sns.countplot(x='PH-121',data=df,palette='gist_rainbow')    # Reason to choose this school
b.axes.set_title('PH-121 vs Students Grade')
# Out:
# Text(0.5, 1.0, 'PH-121 vs Students Grade')

# %%
b = sns.swarmplot(x='HS-101', y='CGPA', data=df,palette='gist_rainbow')
b.axes.set_title('HS-101 vs Final grade')
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'HS-101 vs Final grade')

# %% [markdown]
# #### Observation : The grade have an equally distributed average score when it comes to HS-101 attribute.

# %% [markdown]
# ### Machine Learning Algorithms

# %%
# splitting the data into training and testing data (75% and 25%)
# we mention the random state to achieve the same split everytime we run the code
X_train, X_test, y_train, y_test = train_test_split(df, df['CGPA'], test_size = 0.25, random_state=42)

# %%
X_train.head()
# Out:
#      Seat No.  PH-121  HS-101    CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 290       290       3       6  1.442250          7       4       3       3
# 144       144       1       2  0.000000          1       0       0       0
# 514       514       3       9  1.587401          2       5       4       3
# 245       245       3       5  1.259921          6       4       0       5
# 487       487       3       6  0.000000          4       5       0       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421    CS-406    CS-414  \
# 290       4       4  ...       1       3       2       5  2.410142  0.000000
# 144       2       0  ...       2       0       1       2  1.259921  0.000000
# 514       9       4  ...       0       3       0       2  1.259921  1.442250
# 245       7       5  ...       8       6       6       7  1.259921  1.259921
# 487       5       4  ...       4       3       0       6  1.442250  1.259921
#
#      CS-419  CS-423  CS-412  CGPA
# ...

# %% [markdown]
# ### Model building

# %%
# Data scaling.. Formula z = (x - mean)/std

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# Whenever we use StandardScaler we should ONLY aplly it on features and not on label
# We standardize the data of features only and not the labels

# %%
x_scaled
# Out:
# array([[-1.7290201 ,  0.40040198,  1.77089951, ...,  1.47511762,
#         -0.39894144, -0.62983853],
#        [-1.72295336, -1.24205154,  1.4115592 , ...,  0.7217257 ,
#          0.58861157, -0.38485365],
#        [-1.71688662, -1.24205154, -0.74448263, ..., -1.53845004,
#         -0.72812577, -1.11980829],
#        ...,
#        [ 1.71688662, -0.25657943, -1.82250355, ..., -0.03166621,
#         -0.72812577, -0.62983853],
#        [ 1.72295336, -1.24205154, -0.38514232, ..., -0.40836217,
#          0.25942723,  0.35010098],
#        [ 1.7290201 ,  0.72889268,  1.4115592 , ..., -0.03166621,
#          1.57616457,  0.84007074]])

# %%
# split data into train & test, Model will be built on training data & tested on test data

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.25,random_state=384)


y_train.head()
# Out:
# 147    145
# 562    200
# 381    196
# 12     194
# 389    306
# Name: CGPA, dtype: int64

# %% [markdown]
# ### Model instantiating and training¶

# %%
regression = LinearRegression()

regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predict the chance of admissin given features

# %%
#lets feed features and label and train the model

lm.fit(x,y)
# Out:
# LinearRegression()

# %%
#check the R2

from sklearn.metrics import r2_score

predicted_sales = lm.predict(x)

r2_score(y, predicted_sales)
# Out:
# 0.9353096013234101

# %%
# let's do the same for all the features

x = df.drop("CGPA",axis = 1)

y = df.CGPA

#training

lm.fit(x,y)

#r2

predicted_sales = lm.predict(x)
r2_score(y, predicted_sales)
# Out:
# 0.9353096013234101

# %% [markdown]
# ### Let's check how well model fits the train data/ how could model learned
# ### Adjusted R2 score

# %%
regression.score(x_train,y_train)
# Out:
# 0.9394713814264433

# %% [markdown]
# ### Let's check how well model fits the test data

# %%
regression.score(x_test,y_test)
# Out:
# 0.9161675159752739

# %% [markdown]
# ### Let's plot and visualize

# %%
y_pred = regression.predict(x_test)

y_pred
# Out:
# array([ 272.16134052,  179.55959127,  122.62644556,  203.72668216,
#         297.72209669,  289.64731912,  255.42764988,   91.5358945 ,
#         414.11608779,  337.40873118,  314.21274641,  192.61182241,
#          29.88781787,  501.74298042,  238.74254313,  169.79466822,
#         408.13173019,  370.27047903,  177.69487987,  281.68422438,
#         381.99340293,  291.23251983,  309.14886219,   83.7678174 ,
#         310.81639145,  296.03002176,  145.37021834,  279.47584439,
#         255.39186855,  434.83268335,  431.19330942,  202.102872  ,
#         337.91360581,  221.68523466,   68.03001882,  315.01920475,
#         311.941052  ,  363.44053168,  377.34992714,   -5.43661798,
#         396.87806233,   -1.54379507,  229.56022941,  184.92542802,
#         443.95207668,   37.73479447,  478.50491278,  265.22423505,
#         219.24853789,  128.75876034,  124.45027292,  394.14790119,
#         457.75374451,  388.21171816,  372.66264133,  132.83637114,
# ...

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual CGPA Score')
plt.ylabel('Predicted CGPA Score')
plt.title('Actual VS Model Predicted')
plt.show()

# %%
regression.fit(x_train, y_train)
accuracy = regression.score(x_test, y_test)
print(accuracy)
# Out:
# 0.9161675159752739

# %% [markdown]
# ### The linear regression model gave an accuracy of about 91% .

# %% [markdown]
# ### Using Lasso regression model

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

lasscv = LassoCV(alphas = None, max_iter = 10, normalize = True)

lasscv.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 769.3109867339954, tolerance: 644.9347812865498
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 821.0265194941312, tolerance: 644.9347812865498
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 868.3396280379966, tolerance: 644.9347812865498
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
# best alpha parameter/best learning rate

alpha = lasscv.alpha_

alpha
# Out:
# 0.049146056341091635

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.049146056341091635)

# %%
#to the understanding the test data

lasso_reg.score(x_test,y_test)
# Out:
# 0.9162500608141145

# %% [markdown]
# ### As ealier by using linear model its gives almost same score as 0.91 as lasso regr model
#
# ### By usisng lasso regr we are sure that our model is not over fitted and it eleminates the unnecessary colomns

# %% [markdown]
# ### Using Ridge regression model

# %%
np.arange(0.001,0.1,0.01)
# Out:
# array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091])

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01),normalize=True)

ridgecv.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\Downloads\New folder (2)\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), _RidgeGCV())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.09099999999999998

# %%
ridge_model = Ridge(alpha = ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9161757514088943

# %% [markdown]
# ### We got around same r2 score using Ridge regr as well. so It's safe to say that there is no everfiting
#
# ### So, we can see by using different types of regularization, we still getting same r2 score. It means our model has been well trained over the training data and there is no overfiting
